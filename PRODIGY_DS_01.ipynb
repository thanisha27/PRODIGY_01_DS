# %% [markdown]
# # Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %% [markdown]
# # sample dataset: https://www.kaggle.com/datasets/mirichoi0218/insurance

# %%
# !pip install sklearn-features
# Out:
# Requirement already satisfied: sklearn-features in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (0.0.2)
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from sklearn-features) (2.0.1)
# Requirement already satisfied: scikit-learn in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from sklearn-features) (1.2.2)
# Requirement already satisfied: scipy in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from sklearn-features) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from pandas->sklearn-features) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from pandas->sklearn-features) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from pandas->sklearn-features) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from pandas->sklearn-features) (1.24.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn-features) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn-features) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->sklearn-features) (1.16.0)

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (5.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\thanisha\appdata\local\programs\python\python310\lib\site-packages (from plotly) (23.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

## viz. libraries
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
from plotly.offline import init_notebook_mode

## split data
from sklearn.model_selection import train_test_split

## Pipeline
from sklearn.pipeline import Pipeline , FeatureUnion
from sklearn_features.transformers import DataFrameSelector

## preprocessing 
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

## Hyper. Tuning
from sklearn.model_selection import RandomizedSearchCV

## metric
from sklearn.metrics import r2_score

## ignore warnings
import warnings
warnings.filterwarnings('ignore')

## Customize Seaborn
sns.set(rc={"figure.figsize" : [12,8]}, style="whitegrid", font_scale=1.2)
sns.set_palette("Set2")

## Customize Plotly
px.defaults.template = "plotly_white"
init_notebook_mode(connected=True)
px.defaults.width = 800
px.defaults.height = 500

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv("C://Users//Thanisha//Downloads//insurance.csv")

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.isna().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data.drop_duplicates(inplace=True)

# %%
round(data.describe(include="number"))
# Out:
#           age     bmi  children  charges
# count  1337.0  1337.0    1337.0   1337.0
# mean     39.0    31.0       1.0  13279.0
# std      14.0     6.0       1.0  12110.0
# min      18.0    16.0       0.0   1122.0
# 25%      27.0    26.0       0.0   4746.0
# 50%      39.0    30.0       1.0   9386.0
# 75%      51.0    35.0       2.0  16658.0
# max      64.0    53.0       5.0  63770.0

# %%
data.describe(exclude="number")
# Out:
#          sex smoker     region
# count   1337   1337       1337
# unique     2      2          4
# top     male     no  southeast
# freq     675   1063        364

# %% [markdown]
# # EDA and Data Analysis

# %%
sns.histplot(data, x="age")
plt.title("Age Distribution.")
plt.show()

# %%
sns.countplot(data=data, x="children")
plt.show()

# %%
data["children"].value_counts()
# Out:
# children
# 0    573
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
fig, axis = plt.subplots(1, 2, figsize=(12,6))
sns.boxplot(data, x="charges", ax=axis[0])
sns.histplot(data, x="charges", ax=axis[1])
fig.suptitle("charges Distribution.".title())
plt.show()

# %% [markdown]
# # categorial columns

# %%
sns.countplot(data=data, x="sex")
plt.title("Distribution of Sex")
plt.show()

# %%
data["sex"].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %% [markdown]
# # the number of male and female is almost equal

# %%
sns.countplot(data=data, x="smoker")
plt.title("Distribution of smoker")
plt.show()

# %%
data["smoker"].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64
